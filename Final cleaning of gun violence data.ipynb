# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
# Define path

path = r'/Users/lucerovargas/Documents/Data Analysis/Data Immersion/Achievement 6- Sourcing Open Data'

# %%
# Import cleaned data set 

df = pd.read_csv(os.path.join(path, 'Prepared Data', 'Final_cleaned_data.csv'), index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0  incident_id        date     state city_or_county  \
# 0         278        92383  2014-01-01  New York         Queens
# 1         279        92142  2014-01-01  New York       Brooklyn
# 2         280        95261  2014-01-01  Missouri    Springfield
# 3         281        92272  2014-01-01   Georgia       Columbus
# 4         282        92428  2014-01-01  New York       Syracuse
#
#                        address  n_killed  n_injured  \
# 0                 113th Avenue         1          0
# 1              St. Johns Place         0          1
# 2     Beverly Hills and Temple         0          1
# 3             1327 23rd Street         0          1
# 4  200 block of Ballard Avenue         0          1
#
#                                        incident_url  \
# 0  http://www.gunviolencearchive.org/incident/92383
# 1  http://www.gunviolencearchive.org/incident/92142
# 2  http://www.gunviolencearchive.org/incident/95261
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.shape
# Out:
# (142112, 19)

# %%
df.head()
# Out:
#    incident_id        date     state city_or_county  \
# 0        92383  2014-01-01  New York         Queens
# 1        92142  2014-01-01  New York       Brooklyn
# 2        95261  2014-01-01  Missouri    Springfield
# 3        92272  2014-01-01   Georgia       Columbus
# 4        92428  2014-01-01  New York       Syracuse
#
#                        address  n_killed  n_injured  \
# 0                 113th Avenue         1          0
# 1              St. Johns Place         0          1
# 2     Beverly Hills and Temple         0          1
# 3             1327 23rd Street         0          1
# 4  200 block of Ballard Avenue         0          1
#
#                                        incident_url  \
# 0  http://www.gunviolencearchive.org/incident/92383
# 1  http://www.gunviolencearchive.org/incident/92142
# 2  http://www.gunviolencearchive.org/incident/95261
# 3  http://www.gunviolencearchive.org/incident/92272
# 4  http://www.gunviolencearchive.org/incident/92428
#
# ...

# %%
# Export cleaned data

df.to_csv(os.path.join(path, 'Prepared Data', 'Final_cleaned_data.csv'))
