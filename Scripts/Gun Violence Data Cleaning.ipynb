# %% [markdown]
# ### Importing Libraries

# %%
# Importing libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/lucerovargas/Documents/Documents/Data Analysis/Data Immersion/Achievement 6- Sourcing Open Data'

# %%
# Import data set "gun-violence.csv" file into Jupyter as df

df = pd.read_csv(os.path.join(path, 'Original Data', 'gun-violence.csv'), index_col = False)

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
df.shape
# Out:
# (239677, 29)

# %% [markdown]
# ### Data Consistency Checks

# %%
df.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# gun_stolen                      object
# gun_type                        object
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_name                object
# participant_relationship        object
# ...

# %% [markdown]
# #### Mixed-typed data

# %%
# Check for mixed-typed data

for col in df.columns.tolist():
    weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
    if len(df[weird]) > 0:
        print(col)
# Out:
# address
# source_url
# gun_stolen
# gun_type
# incident_characteristics
# location_description
# notes
# participant_age
# participant_age_group
# participant_gender
# participant_name
# participant_relationship
# participant_status
# participant_type
# sources

# %%
# change the data types so they are no longer mixed

df['address'] = df['address'].astype('str')
df['source_url'] = df['source_url'].astype('str')
df['incident_characteristics'] = df['incident_characteristics'].astype('str')
df['location_description'] = df['location_description'].astype('str')
df['notes'] = df['notes'].astype('str')
df['participant_age'] = df['participant_age'].astype('str')
df['participant_age_group'] = df['participant_age_group'].astype('str')
df['participant_gender'] = df['participant_gender'].astype('str')
df['participant_relationship'] = df['participant_relationship'].astype('str')
df['participant_status'] = df['participant_status'].astype('str')
df['participant_type'] = df['participant_type'].astype('str')
df['sources'] = df['sources'].astype('str')

# %%
# Deleting the following columns as the information is not needed for this analysis.

df = df.drop(columns = ['gun_stolen'])
df = df.drop(columns = ['gun_type'])
df = df.drop(columns = ['participant_name'])

# %%
df.dtypes
# Out:
# incident_id                      int64
# date                            object
# state                           object
# city_or_county                  object
# address                         object
# n_killed                         int64
# n_injured                        int64
# incident_url                    object
# source_url                      object
# incident_url_fields_missing       bool
# congressional_district         float64
# incident_characteristics        object
# latitude                       float64
# location_description            object
# longitude                      float64
# n_guns_involved                float64
# notes                           object
# participant_age                 object
# participant_age_group           object
# participant_gender              object
# participant_relationship        object
# participant_status              object
# participant_type                object
# sources                         object
# ...

# %% [markdown]
# #### Missing Values

# %%
# Look for missing values
df.isnull().sum()
# Out:
# incident_id                        0
# date                               0
# state                              0
# city_or_county                     0
# address                            0
# n_killed                           0
# n_injured                          0
# incident_url                       0
# source_url                         0
# incident_url_fields_missing        0
# congressional_district         11944
# incident_characteristics           0
# latitude                        7923
# location_description               0
# longitude                       7923
# n_guns_involved                99451
# notes                              0
# participant_age                    0
# participant_age_group              0
# participant_gender                 0
# participant_relationship           0
# participant_status                 0
# participant_type                   0
# sources                            0
# state_house_district           38772
# ...

# %%
# Deleting columns that are not necessary for analysis

df = df.drop(columns = ['congressional_district'])
df = df.drop(columns = ['latitude'])
df = df.drop(columns = ['longitude']) 
df = df.drop(columns = ['state_house_district'])
df = df.drop(columns = ['state_senate_district'])

# %% [markdown]
# Will not drop n_guns_involved, that will remove too much data

# %% [markdown]
# #### Duplicates

# %%
df_dups = df[df.duplicated()]

# %% [markdown]
# There are no duplicates, no action taken

# %% [markdown]
# #### Consistency checks

# %%
df.describe()
# Out:
#         incident_id       n_killed      n_injured  n_guns_involved
# count  2.396770e+05  239677.000000  239677.000000    140226.000000
# mean   5.593343e+05       0.252290       0.494007         1.372442
# std    2.931287e+05       0.521779       0.729952         4.678202
# min    9.211400e+04       0.000000       0.000000         1.000000
# 25%    3.085450e+05       0.000000       0.000000         1.000000
# 50%    5.435870e+05       0.000000       0.000000         1.000000
# 75%    8.172280e+05       0.000000       1.000000         1.000000
# max    1.083472e+06      50.000000      53.000000       400.000000

# %% [markdown]
# #### Remove any remaining columns not needed for analysis

# %%
df.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
# Delete columns 

df = df.drop(columns = ['incident_url_fields_missing'])
df = df.drop(columns = ['participant_age_group'])

# %%
# Review shape

df.shape
# Out:
# (239677, 19)

# %%
df.dtypes
# Out:
# incident_id                   int64
# date                         object
# state                        object
# city_or_county               object
# address                      object
# n_killed                      int64
# n_injured                     int64
# incident_url                 object
# source_url                   object
# incident_characteristics     object
# location_description         object
# n_guns_involved             float64
# notes                        object
# participant_age              object
# participant_gender           object
# participant_relationship     object
# participant_status           object
# participant_type             object
# sources                      object
# dtype: object

# %% [markdown]
# ### Export Data Set

# %%
df.to_csv(os.path.join(path, 'Prepared Data', 'Data_clean.csv'))
